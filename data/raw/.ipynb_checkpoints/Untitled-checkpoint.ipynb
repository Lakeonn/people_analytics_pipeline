# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\letov\Projects\people_analytics\data\raw\events.csv")

# %%
list(df.columns)
# Out:
# ['employee_id',
#  'first_name',
#  'last_name',
#  'gender',
#  'birth_date',
#  'hire_date',
#  'termination_date',
#  'country',
#  'city',
#  'job_title',
#  'department',
#  'manager_id',
#  'salary',
#  'created_at',
#  'updated_at']
