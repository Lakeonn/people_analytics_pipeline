# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\letov\Projects\people_analytics\data\raw\events.csv")

# %%
list(df.columns)
# Out:
# ['event_id',
#  'employee_id',
#  'event_type',
#  'event_date',
#  'new_job_title',
#  'new_department',
#  'new_salary',
#  'created_at']
